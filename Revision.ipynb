# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
#if condition
age = int (input("Enter Your Age:"))
if age>=18:
 print("You are eligible for voting")
# Out:
# You are eligible for voting

# %%
#if eles condition
age = int(input("Enter Your Age:"))
if age>=18:
    print("You are eligible for voting")
else:
    print("You are not eligble for voting")
# Out:
# You are not eligble for voting

# %%
age = int (input("Enter your age:"))
if age<5:
    print("Child")
elif age >=5 and age <18:
    print("Teenager")
elif age >=18 and age<60:
    print("Adult")
elif age>=60:
    print("Senior Citizen")
# Out:
# Teenager

# %%
marks = int(input("Enter your marks:"))
if marks>90:
    print("A+")
elif marks>80:
    print("A")
elif marks>70:
    print ("B+")
elif marks>60:
    print("B")
elif marks>50:
    print("C+")
elif marks>40:
        print("C")
else:
    print("Fail")
# Out:
# C

# %%
num = int (input("Enter a number:"))
if num>0:
    print("positve")
else:
    print("Negative")

    
if num%2==0:
    print("Even")
else:
    print("Odd")
# Out:
# Negative
# Odd

# %%
import pyjokes
joke = pyjokes.get_joke()
print (joke)
# Out:
# The C language combines all the power of assembly language with all the ease-of-use of assembly language.

# %%
import pyttsx3
engine = pyttsx3.init()
engine.say("I am abdul malik khan and i am studying in abes engineering college and i am in 2nd year of btech ")
engine.runAndWait()
